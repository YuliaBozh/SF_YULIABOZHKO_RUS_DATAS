# %% [markdown]
# <center> <img src = https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/hh%20label.jpg alt="drawing" style="width:400px;">

# %% [markdown]
# # <center> Проект: Анализ резюме из HeadHunter

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#import plotly.express as px

# %% [markdown]
# # Исследование структуры данных

# %% [markdown]
# 1. Прочитайте данные с помощью библиотеки Pandas. Совет: перед чтением обратите внимание на разделитель внутри файла.

# %%
#ваш код здесь
import pandas as pd

# Чтение данных из файла с учетом разделителя
file_path = 'data/dst-3.0_16_1_hh_database.csv'
data = pd.read_csv(file_path, sep=';')  # Разделитель - точка с запятой

# Определение размерности таблицы
data_shape = data.shape
data_shape
# Out:
# (44744, 12)

# %% [markdown]
# 2. Выведите несколько первых (последних) строк таблицы, чтобы убедиться в том, что ваши данные не повреждены. Ознакомьтесь с признаками и их структурой.

# %%
#ваш код здесь
import pandas as pd

data = pd.read_csv('data/dst-3.0_16_1_hh_database.csv', sep=';')
data.head()
# Out:
#                                    Пол, возраст           ЗП  \
# 0    Мужчина ,  39 лет , родился 27 ноября 1979   29000 руб.
# 1     Мужчина ,  60 лет , родился 20 марта 1959   40000 руб.
# 2  Женщина ,  36 лет , родилась 12 августа 1982   20000 руб.
# 3      Мужчина ,  38 лет , родился 25 июня 1980  100000 руб.
# 4     Женщина ,  26 лет , родилась 3 марта 1993  140000 руб.
#
#                            Ищет работу на должность:  \
# 0                            Системный администратор
# 1                               Технический писатель
# 2                                           Оператор
# 3  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4                  Региональный менеджер по продажам
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
# 1  Королев , не готов к переезду , готов к редким...
# 2  Тверь , не готова к переезду , не готова к ком...
# 3  Саратов , не готов к переезду , готов к редким...
# ...

# %% [markdown]
# 3. Выведите основную информацию о числе непустых значений в столбцах и их типах в таблице.

# %% [markdown]
# 4. Обратите внимание на информацию о числе непустых значений.

# %%
import pandas as pd

# Чтение файла с предполагаемым разделителем
file_path = 'data/dst-3.0_16_1_hh_database.csv'
data = pd.read_csv(file_path, sep=';')  # Разделитель - точка с запятой
# Вывод основной информации о таблице
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Пол, возраст                     44744 non-null  object
#  1   ЗП                               44744 non-null  object
#  2   Ищет работу на должность:        44744 non-null  object
#  3   Город, переезд, командировки     44744 non-null  object
#  4   Занятость                        44744 non-null  object
#  5   График                           44744 non-null  object
#  6   Опыт работы                      44576 non-null  object
#  7   Последнее/нынешнее место работы  44743 non-null  object
#  8   Последняя/нынешняя должность     44742 non-null  object
#  9   Образование и ВУЗ                44744 non-null  object
#  10  Обновление резюме                44744 non-null  object
#  11  Авто                             44744 non-null  object
# ...

# %% [markdown]
# 5. Выведите основную статистическую информацию о столбцах.

# %%
import pandas as pd

# Чтение файла с предполагаемым разделителем
file_path = 'data/dst-3.0_16_1_hh_database.csv'
data = pd.read_csv(file_path, sep=';')  # Разделитель - точка с запятой

# Вывод статистической информации о таблице
description = data.describe(include='all')

# Подсчет уникальных значений в столбце "Опыт работы"
unique_experience = data['Опыт работы'].nunique()

# Нахождение самой распространённой искомой должности
most_common_position = data['Ищет работу на должность:'].mode()[0]

print(description)
print("Уникальных значений в столбце 'Опыт работы':", unique_experience)
print("Самая распространённая искомая должность:", most_common_position)
# Out:
#                                          Пол, возраст          ЗП  \
# count                                           44744       44744
# unique                                          16003         690
# top     Мужчина ,  32 года , родился 17 сентября 1986  50000 руб.
# freq                                               18        4064
#
#        Ищет работу на должность:  \
# count                      44744
# unique                     14929
# top      Системный администратор
# freq                        3099
#
#                              Город, переезд, командировки         Занятость  \
# count                                               44744             44744
# unique                                              10063                38
# top     Москва , не готов к переезду , не готов к кома...  полная занятость
# freq                                                 1261             30026
#
#              График                                        Опыт работы  \
# ...

# %% [markdown]
# # Преобразование данных

# %% [markdown]
# 1. Начнем с простого - с признака **"Образование и ВУЗ"**. Его текущий формат это: **<Уровень образования год выпуска ВУЗ специальность...>**. Например:
# * Высшее образование 2016 Московский авиационный институт (национальный исследовательский университет)...
# * Неоконченное высшее образование 2000  Балтийская государственная академия рыбопромыслового флота…
# Нас будет интересовать только уровень образования.
#
# Создайте с помощью функции-преобразования новый признак **"Образование"**, который должен иметь 4 категории: "высшее", "неоконченное высшее", "среднее специальное" и "среднее".
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак "Образование и ВУЗ".
#
# Совет: обратите внимание на структуру текста в столбце **"Образование и ВУЗ"**. Гарантируется, что текущий уровень образования соискателя всегда находится в первых 2ух слов и начинается с заглавной буквы. Воспользуйтесь этим.
#
# *Совет: проверяйте полученные категории, например, с помощью метода unique()*

# %%
import pandas as pd

# Загрузка данных
data = pd.read_csv('data/dst-3.0_16_1_hh_database.csv', sep=';')

def extract_education_level(text):
    # Определение категорий образования
    if 'Высшее образование' in text:
        return 'высшее'
    elif 'Неоконченное высшее образование' in text:
        return 'неоконченное высшее'
    elif 'Среднее специальное' in text:
        return 'среднее специальное'
    elif 'Среднее образование' in text:
        return 'среднее'
    else:
        return 'другое'


# Применение функции к столбцу 'Образование и ВУЗ'
data['Образование'] = data['Образование и ВУЗ'].apply(extract_education_level)

# Удаление столбца 'Образование и ВУЗ'
data.drop('Образование и ВУЗ', axis=1, inplace=True)

# Путь к файлу для сохранения
output_file_path = 'data/dst-education_hh_database.csv'

# Сохранение изменённого DataFrame в файл
data.to_csv(output_file_path, sep=';', index=False)

# Получение информации о DataFrame
data.info()

# Контрольные вопросы
num_higher_education = data[data['Образование'] == 'высшее'].shape[0]
num_secondary_education = data[data['Образование'] == 'среднее специальное'].shape[0]
num_education = data[data['Образование'] == 'среднее'].shape[0]
num_unfinish_higher_education = data[data['Образование'] == 'неоконченное высшее'].shape[0]
num_others = data[data['Образование'] == 'другое'].shape[0]
num_higher_education, num_secondary_education, num_education, num_unfinish_higher_education, num_others,
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Пол, возраст                     44744 non-null  object
#  1   ЗП                               44744 non-null  object
#  2   Ищет работу на должность:        44744 non-null  object
#  3   Город, переезд, командировки     44744 non-null  object
#  4   Занятость                        44744 non-null  object
#  5   График                           44744 non-null  object
#  6   Опыт работы                      44576 non-null  object
#  7   Последнее/нынешнее место работы  44743 non-null  object
#  8   Последняя/нынешняя должность     44742 non-null  object
#  9   Обновление резюме                44744 non-null  object
#  10  Авто                             44744 non-null  object
#  11  Образование                      44744 non-null  object
# ...

# %% [markdown]
# 2. Теперь нас интересует столбец **"Пол, возраст"**. Сейчас он представлен в формате **<Пол , возраст , дата рождения >**. Например:
# * Мужчина , 39 лет , родился 27 ноября 1979
# * Женщина , 21 год , родилась 13 января 2000
# Как вы понимаете, нам необходимо выделить каждый параметр в отдельный столбец.
#
# Создайте два новых признака **"Пол"** и **"Возраст"**. При этом важно учесть:
# * Признак пола должен иметь 2 уникальных строковых значения: 'М' - мужчина, 'Ж' - женщина.
# * Признак возраста должен быть представлен целыми числами.
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак **"Пол, возраст"** из таблицы.
#
# *Совет: обратите внимание на структуру текста в столбце, в части на то, как разделены параметры пола, возраста и даты рождения между собой - символом ' , '.
# Гарантируется, что структура одинакова для всех строк в таблице. Вы можете воспользоваться этим.*

# %%
import pandas as pd

# Загрузка данных
data = pd.read_csv('data/dst-education_hh_database.csv', sep=';')

def extract_gender_and_age(text):
    # Разделение строки на компоненты
    parts = text.split(',')
    # Извлечение пола
    gender = 'М' if 'Мужчина' in parts[0] else 'Ж'
    # Извлечение возраста
    age = int(parts[1].split()[0])
    return gender, age

# Применение функции и создание новых столбцов
data['Пол'], data['Возраст'] = zip(*data['Пол, возраст'].apply(extract_gender_and_age))

# Удаление старого столбца 'Пол, возраст'
data.drop('Пол, возраст', axis=1, inplace=True)

# Путь к файлу для сохранения
output_file_path = 'data/dst-education__age_gender_hh_database.csv'
# Сохранение изменённого DataFrame в файл
data.to_csv(output_file_path, sep=';', index=False)

# Контрольные вопросы
num_males = data[data['Пол'] == 'М'].shape[0]
num_females = data[data['Пол'] == 'Ж'].shape[0]
average_age = data['Возраст'].mean()

num_females, num_males, average_age

# Подсчет общего количества резюме и количества резюме женщин
total_resumes = data.shape[0]
female_resumes = data[data['Пол'] == 'Ж'].shape[0]

# Расчет процента женских резюме
percentage_female_resumes = (female_resumes / total_resumes) * 100
rounded_percentage = round(percentage_female_resumes, 2)

rounded_percentage
# Out:
# 19.07

# %%
import pandas as pd

# Загрузка данных
data = pd.read_csv('data/dst-education_hh_database.csv', sep=';')

def extract_gender_and_age(text):
    # Разделение строки на компоненты
    parts = text.split(',')
    # Извлечение пола
    gender = 'М' if 'Мужчина' in parts[0] else 'Ж'
    # Извлечение возраста
    age = int(parts[1].split()[0])
    return gender, age

# Применение функции и создание новых столбцов
data['Пол'], data['Возраст'] = zip(*data['Пол, возраст'].apply(extract_gender_and_age))

# Удаление старого столбца 'Пол, возраст'
data.drop('Пол, возраст', axis=1, inplace=True)

# Контрольные вопросы
num_males = data[data['Пол'] == 'М'].shape[0]
num_females = data[data['Пол'] == 'Ж'].shape[0]
average_age = data['Возраст'].mean()
rounded_average_age = round(average_age, 1)

num_females, num_males, rounded_average_age
# Out:
# (8533, 36211, 32.2)

# %% [markdown]
# 3. Следующим этапом преобразуем признак **"Опыт работы"**. Его текущий формат - это: **<Опыт работы: n лет m месяцев, периоды работы в различных компаниях…>**.
#
# Из столбца нам необходимо выделить общий опыт работы соискателя в месяцах, новый признак назовем "Опыт работы (месяц)"
#
# Для начала обсудим условия решения задачи:
# * Во-первых, в данном признаке есть пропуски. Условимся, что если мы встречаем пропуск, оставляем его как есть (функция-преобразование возвращает NaN)
# * Во-вторых, в данном признаке есть скрытые пропуски. Для некоторых соискателей в столбце стоит значения "Не указано". Их тоже обозначим как NaN (функция-преобразование возвращает NaN)
# * В-третьих, нас не интересует информация, которая описывается после указания опыта работы (периоды работы в различных компаниях)
# * В-четвертых, у нас есть проблема: опыт работы может быть представлен только в годах или только месяцах. Например, можно встретить следующие варианты:
#     * Опыт работы 3 года 2 месяца…
#     * Опыт работы 4 года…
#     * Опыт работы 11 месяцев…
#     * Учитывайте эту особенность в вашем коде
#
# Учитывайте эту особенность в вашем коде
#
# В результате преобразования у вас должен получиться столбец, содержащий информацию о том, сколько месяцев проработал соискатель.
# Выполните преобразование, ответьте на контрольные вопросы и удалите столбец **"Опыт работы"** из таблицы.

# %%
import pandas as pd
import numpy as np
# Загрузка данных
data = pd.read_csv('data/dst-education__age_gender_hh_database.csv', sep=';')

def get_experience(arg):
    if arg is np.nan or arg == "не указано":
        return np.nan
    year_list = ['год', 'года', 'лет']
    months_list = ['месяц', 'месяцев', 'месяца']
    list_exp = arg.split()[2:7]
    years = 0
    months = 0
    for index, item in enumerate(list_exp):
        if item in year_list:
            years = int(list_exp[index-1])
        if item in months_list:
            months = int(list_exp[index-1])
    return int(years*12 + months)
    
data["Опыт работы (месяц)"] = data["Опыт работы"].apply(get_experience)  

data.drop('Опыт работы', axis=1, inplace=True)

# Путь к файлу для сохранения
output_file_path = 'data/dst-education_experience_age_gender_hh_database.csv'

# Сохранение изменённого DataFrame в файл
data.to_csv(output_file_path, sep=';', index=False)

# Предполагаем, что столбец 'Опыт работы (месяц)' уже создан
median_experience = data['Опыт работы (месяц)'].median()
data.info()
print("Медианный опыт работы (в месяцах):", median_experience)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ЗП                               44744 non-null  object
#  1   Ищет работу на должность:        44744 non-null  object
#  2   Город, переезд, командировки     44744 non-null  object
#  3   Занятость                        44744 non-null  object
#  4   График                           44744 non-null  object
#  5   Последнее/нынешнее место работы  44743 non-null  object
#  6   Последняя/нынешняя должность     44742 non-null  object
#  7   Обновление резюме                44744 non-null  object
#  8   Авто                             44744 non-null  object
#  9   Образование                      44744 non-null  object
#  10  Пол                              44744 non-null  object
#  11  Возраст                          44744 non-null  int64
# ...

# %% [markdown]
# 4. Хорошо идем! Следующий на очереди признак "Город, переезд, командировки". Информация в нем представлена в следующем виде: **<Город , (метро) , готовность к переезду (города для переезда) , готовность к командировкам>**. В скобках указаны необязательные параметры строки. Например, можно встретить следующие варианты:
#
# * Москва , не готов к переезду , готов к командировкам
# * Москва , м. Беломорская , не готов к переезду, не готов к командировкам
# * Воронеж , готов к переезду (Сочи, Москва, Санкт-Петербург) , готов к командировкам
#
# Создадим отдельные признаки **"Город"**, **"Готовность к переезду"**, **"Готовность к командировкам"**. При этом важно учесть:
#
# * Признак **"Город"** должен содержать только 4 категории: "Москва", "Санкт-Петербург" и "город-миллионник" (их список ниже), остальные обозначьте как "другие".
#
#     Список городов-миллионников:
#
#    <code>million_cities = ['Новосибирск', 'Екатеринбург','Нижний Новгород','Казань', 'Челябинск','Омск', 'Самара', 'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 'Воронеж','Волгоград']
#     </code>
#     Инфорация о метро, рядом с которым проживает соискатель нас не интересует.
# * Признак **"Готовность к переезду"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к переезду в признаке "Город, переезд, командировки". Например:
#     * … , готов к переезду , …
#     * … , не готова к переезду , …
#     * … , готова к переезду (Москва, Санкт-Петербург, Ростов-на-Дону)
#     * … , хочу переехать (США) , …
#
#     Нас интересует только сам факт возможности или желания переезда.
# * Признак **"Готовность к командировкам"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к командировкам в признаке "Город, переезд, командировки". Например:
#     * … , готов к командировкам , …
#     * … , готова к редким командировкам , …
#     * … , не готов к командировкам , …
#
#     Нас интересует только сам факт готовности к командировке.
#
#     Еще один важный факт: при выгрузки данных у некоторых соискателей "потерялась" информация о готовности к командировкам. Давайте по умолчанию будем считать, что такие соискатели не готовы к командировкам.
#
# Выполните преобразования и удалите столбец **"Город, переезд, командировки"** из таблицы.
#
# *Совет: обратите внимание на то, что структура текста может меняться в зависимости от указания ближайшего метро. Учите это, если будете использовать порядок слов в своей программе.*

# %%
import pandas as pd
import numpy as np
# Загрузка данных
data = pd.read_csv('data/dst-education_experience_age_gender_hh_database.csv', sep=';')

million_cities = ['Новосибирск', 'Екатеринбург', 'Нижний Новгород', 'Казань', 'Челябинск', 
                  'Омск', 'Самара', 'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 'Воронеж', 'Волгоград']

def extract_city_relocation_business_trips(text):
    parts = text.split(',')
    city = parts[0].strip()
    relocation = 'готов к переезду' in text or 'готова к переезду' in text or 'хочу переехать' in text
    business_trips = 'готов к командировкам' in text or 'готова к командировкам' in text or 'готов к редким командировкам' in text or 'готова к редким командировкам' in text

    if city not in million_cities and city != 'Москва' and city != 'Санкт-Петербург':
        city = 'другие'
    return city, relocation, business_trips

# Применение функции к столбцу и создание новых столбцов
data['Город'], data['Готовность к переезду'], data['Готовность к командировкам'] = zip(*data['Город, переезд, командировки'].apply(extract_city_relocation_business_trips))

# Удаление старого столбца 'Город, переезд, командировки'
data.drop('Город, переезд, командировки', axis=1, inplace=True)

# Путь к файлу для сохранения
output_file_path = 'data/dst-education_city_move_experience_age_gender_hh_database.csv'

# Сохранение изменённого DataFrame в файл
data.to_csv(output_file_path, sep=';', index=False)
# Подсчет общего количества и соискателей из Санкт-Петербурга
total_applicants = data.shape[0]
spb_applicants = data[data['Город'] == 'Санкт-Петербург'].shape[0]

# Расчет процента
percentage_spb_applicants = (spb_applicants / total_applicants) * 100
rounded_percentage = round(percentage_spb_applicants)


# Просмотр результатов
data.info()
print("Процент соискателей из Санкт-Петербурга:", rounded_percentage)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 15 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ЗП                               44744 non-null  object
#  1   Ищет работу на должность:        44744 non-null  object
#  2   Занятость                        44744 non-null  object
#  3   График                           44744 non-null  object
#  4   Последнее/нынешнее место работы  44743 non-null  object
#  5   Последняя/нынешняя должность     44742 non-null  object
#  6   Обновление резюме                44744 non-null  object
#  7   Авто                             44744 non-null  object
#  8   Образование                      44744 non-null  object
#  9   Пол                              44744 non-null  object
#  10  Возраст                          44744 non-null  int64
#  11  Опыт работы (месяц)              44576 non-null  float64
# ...

# %%
import pandas as pd

# Загрузка данных
data = pd.read_csv('data/dst-education_experience_age_gender_hh_database.csv', sep=';')

# Функции get_dislocate и get_business_trip
def get_dislocate(arg):
    if ('не готов к переезду' in arg) or ('не готова к переезду' in arg):
        return False
    else:
        return True

def get_business_trip(arg):
    if 'командировк' not in arg:
        return False
    if ('не готов к командировкам' in arg) or ('не готова к командировкам' in arg):
        return False
    return True

# Применение функций и создание новых столбцов
data['Готовность к переезду'] = data['Город, переезд, командировки'].apply(get_dislocate)
data['Готовность к командировкам'] = data['Город, переезд, командировки'].apply(get_business_trip)

# Удаление старого столбца
data.drop('Город, переезд, командировки', axis=1, inplace=True)

# Путь к файлу для сохранения
output_file_path = 'data/dst-m2_education_experience_age_gender_hh_database.csv'
# Сохранение изменённого DataFrame в файл
data.to_csv(output_file_path, sep=';', index=False)

# Подсчет процента соискателей, готовых и к переездам, и к командировкам
percentage_ready = data[(data['Готовность к переезду'] == True) & (data['Готовность к командировкам'] == True)].shape[0] / data.shape[0] * 100
rounded_percentage = round(percentage_ready)

rounded_percentage
# Out:
# 32

# %% [markdown]
# 5. Рассмотрим поближе признаки **"Занятость"** и **"График"**. Сейчас признаки представляют собой набор категорий желаемой занятости (полная занятость, частичная занятость, проектная работа, волонтерство, стажировка) и желаемого графика работы (полный день, сменный график, гибкий график, удаленная работа, вахтовый метод).
# На сайте hh.ru соискатель может указывать различные комбинации данных категорий, например:
# * полная занятость, частичная занятость
# * частичная занятость, проектная работа, волонтерство
# * полный день, удаленная работа
# * вахтовый метод, гибкий график, удаленная работа, полная занятость
#
# Такой вариант признаков имеет множество различных комбинаций, а значит множество уникальных значений, что мешает анализу. Нужно это исправить!
#
# Давайте создадим признаки-мигалки для каждой категории: если категория присутствует в списке желаемых соискателем, то в столбце на месте строки рассматриваемого соискателя ставится True, иначе - False.
#
# Такой метод преобразования категориальных признаков называется One Hot Encoding и его схема представлена на рисунке ниже:
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/ohe.jpg>
# Выполните данное преобразование для признаков "Занятость" и "График", ответьте на контрольные вопросы, после чего удалите их из таблицы

# %%
# Перенос кода и исполнение заданных расчетов
import pandas as pd

# Загрузка данных
data = pd.read_csv('data/dst-education_city_move_experience_age_gender_hh_database.csv', sep=';')
employment_categories = ['полная занятость', 'частичная занятость', 'проектная работа', 'волонтерство', 'стажировка']
schedule_categories = ['полный день', 'сменный график', 'гибкий график', 'удалённая работа', 'вахтовый метод']

def encode_employment(x):
    if pd.isna(x):
        return dict.fromkeys(employment_categories, False)
    return {category: category in x for category in employment_categories}

def encode_schedule(x):
    if pd.isna(x):
        return dict.fromkeys(schedule_categories, False)
    return {category: category in x for category in schedule_categories}

# Создание новых признаков-мигалок для 'Занятость' и 'График'
for category in employment_categories + schedule_categories:
    data[category] = False

for index, row in data.iterrows():
    if pd.notna(row['Занятость']):
        for key, value in encode_employment(row['Занятость']).items():
            data.at[index, key] = value
    if pd.notna(row['График']):
        for key, value in encode_schedule(row['График']).items():
            data.at[index, key] = value

# Удаление исходных столбцов
data.drop(['Занятость', 'График'], axis=1, inplace=True)


# Путь к файлу для сохранения
output_file_path = 'data/dst-education_schedule_city_move_experience_age_gender_hh_database.csv'
# Сохранение изменённого DataFrame в файл
data.to_csv(output_file_path, sep=';', index=False)

# Вычисление контрольных значений
part_time_interest = data['частичная занятость'].mean() * 100
remote_work_interest = data['удалённая работа'].mean() * 100
# Подсчет количества людей, ищущих проектную работу и волонтёрство
people_looking_for_project_and_volunteering = data[
    (data['проектная работа'] == True) & (data['волонтерство'] == True)
].shape[0]
# Подсчет количества людей, хотящих работать вахтовым методом и с гибким графиком
people_looking_for_rotational_and_flexible = data[
    (data['вахтовый метод'] == True) & (data['гибкий график'] == True)
].shape[0]


data.info()
part_time_interest, remote_work_interest, people_looking_for_project_and_volunteering, people_looking_for_rotational_and_flexible
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 23 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ЗП                               44744 non-null  object
#  1   Ищет работу на должность:        44744 non-null  object
#  2   Последнее/нынешнее место работы  44743 non-null  object
#  3   Последняя/нынешняя должность     44742 non-null  object
#  4   Обновление резюме                44744 non-null  object
#  5   Авто                             44744 non-null  object
#  6   Образование                      44744 non-null  object
#  7   Пол                              44744 non-null  object
#  8   Возраст                          44744 non-null  int64
#  9   Опыт работы (месяц)              44576 non-null  float64
#  10  Город                            44744 non-null  object
#  11  Готовность к переезду            44744 non-null  bool
# ...

# %% [markdown]
# 6. (2 балла) Наконец, мы добрались до самого главного и самого важного - признака заработной платы **"ЗП"**.
# В чем наша беда? В том, что помимо желаемой заработной платы соискатель указывает валюту, в которой он бы хотел ее получать, например:
# * 30000 руб.
# * 50000 грн.
# * 550 USD
#
# Нам бы хотелось видеть заработную плату в единой валюте, например, в рублях. Возникает вопрос, а где взять курс валют по отношению к рублю?
#
# На самом деле язык Python имеет в арсенале огромное количество возможностей получения данной информации, от обращения к API Центробанка, до использования специальных библиотек, например pycbrf. Однако, это не тема нашего проекта.
#
# Поэтому мы пойдем в лоб: обратимся к специальным интернет-ресурсам для получения данных о курсе в виде текстовых файлов. Например, MDF.RU, данный ресурс позволяет удобно экспортировать данные о курсах различных валют и акций за указанные периоды в виде csv файлов. Мы уже сделали выгрузку курсов валют, которые встречаются в наших данных за период с 29.12.2017 по 05.12.2019. Скачать ее вы можете **на платформе**
#
# Создайте новый DataFrame из полученного файла. В полученной таблице нас будут интересовать столбцы:
# * "currency" - наименование валюты в ISO кодировке,
# * "date" - дата,
# * "proportion" - пропорция,
# * "close" - цена закрытия (последний зафиксированный курс валюты на указанный день).
#
#
# Перед вами таблица соответствия наименований иностранных валют в наших данных и их общепринятых сокращений, которые представлены в нашем файле с курсами валют. Пропорция - это число, за сколько единиц валюты указан курс в таблице с курсами. Например, для казахстанского тенге курс на 20.08.2019 составляет 17.197 руб. за 100 тенге, тогда итоговый курс равен - 17.197 / 100 = 0.17197 руб за 1 тенге.
# Воспользуйтесь этой информацией в ваших преобразованиях.
#
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/table.jpg>
#
#
# Осталось только понять, откуда брать дату, по которой определяется курс? А вот же она - в признаке **"Обновление резюме"**, в нем содержится дата и время, когда соискатель выложил текущий вариант своего резюме. Нас интересует только дата, по ней бы и будем сопоставлять курсы валют.
#
# Теперь у нас есть вся необходимая информация для того, чтобы создать признак "ЗП (руб)" - заработная плата в рублях.
#
# После ответа на контрольные вопросы удалите исходный столбец заработной платы "ЗП" и все промежуточные столбцы, если вы их создавали.

# %% [markdown]
# Итак, давайте обсудим возможный алгоритм преобразования:
# 1. Перевести признак "Обновление резюме" из таблицы с резюме в формат datetime и достать из него дату. В тот же формат привести признак "date" из таблицы с валютами.
# 2. Выделить из столбца "ЗП" сумму желаемой заработной платы и наименование валюты, в которой она исчисляется. Наименование валюты перевести в стандарт ISO согласно с таблицей выше.
# 3. Присоединить к таблице с резюме таблицу с курсами по столбцам с датой и названием валюты (подумайте, какой тип объединения надо выбрать, чтобы в таблице с резюме сохранились данные о заработной плате, изначально представленной в рублях). Значение close для рубля заполнить единицей 1 (курс рубля самого к себе)
# 4. Умножить сумму желаемой заработной платы на присоединенный курс валюты (close) и разделить на пропорцию (обратите внимание на пропуски после объединения в этих столбцах), результат занести в новый столбец "ЗП (руб)".

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Загрузка данных
currency_rates = pd.read_csv('data/ExchangeRates.csv', sep=',')
data = pd.read_csv('data/dst-education_schedule_city_move_experience_age_gender_hh_database.csv', sep=';')

# Преобразуем наименование валюты в стандарт ISO
def currency(feature):

    currency_names = {
                'грн': 'UAH', 'USD': 'USD', 'EUR': 'EUR', 'белруб': 'BYN',
                'KGS': 'KGS', 'сум': 'UZS', 'AZN': 'AZN', 'KZT': 'KZT'
                }
    
    return currency_names.get(feature.split()[1].replace('.',''))

# Объявляем функцию которая создает новый признак 'ЗП (руб)' из признаков 'ЗП', 'close' и 'proportion''
def salary_RUB (features):
    
    if np.isnan(features)[1]:
        return features[0]
   
    else:
        return features[0] * features[1] / features[2]
    
# Считываем новый датасет - выгрузка валют
ExchangeRates = pd.read_csv('data/ExchangeRates.csv')
# Преобразовываем признак 'date' во временной тип данных 
ExchangeRates['date'] = pd.to_datetime(ExchangeRates['date'])

# Удаляем неиспользуемые колонки 'per', 'time', 'vol' из выгрузки валют
ExchangeRates = ExchangeRates.drop(['per', 'time', 'vol'], axis=1)

# Создаем с помощью функции-преобразования временный признак 'Валюта'
data['Валюта'] = data['ЗП'].apply(currency)

# Преобразовываем с помощью функции-преобразования признак 'ЗП'
data['ЗП'] = data['ЗП'].apply(lambda x: float(x.split()[0]))


# Преобразовываем признак 'Обновление резюме' во временной тип данных 
data['Обновление резюме'] = pd.to_datetime(data['Обновление резюме']).dt.date.astype('datetime64[ns]')
# Объединяем основной датасет с выгразками валют по двум полям 
data = data.merge(ExchangeRates, how='left', left_on=['Валюта', 'Обновление резюме'], 
          right_on=['currency', 'date'])

# Создаем с помощью функции-преобразования новый признак 'ЗП (руб)'
data['ЗП (руб)'] = data[['ЗП', 'close', 'proportion']].apply(salary_RUB, axis=1)

# Удаляем неиспользуемые колонки 'ЗП', 'Валюта', 'vol' из основного датасета
data = data.drop(['ЗП', 'Валюта', 'currency', 'date', 'close', 'proportion'], axis=1)

# Путь к файлу для сохранения
output_file_path = 'data/dst-final_hh_database.csv'
# Сохранение изменённого DataFrame в файл
data.to_csv(output_file_path, sep=';', index=False)
# Вычисляем желаемую медианную заработную плату соискателей в нашей таблице (в рублях)
print('Желаемая медианная заработная плата соискателей: {} тыс. рублей'.
      format(round(data['ЗП (руб)'].median() / 1000)))
# Out:
# Желаемая медианная заработная плата соискателей: 59 тыс. рублей

# %% [markdown]
# # Исследование зависимостей в данных

# %% [markdown]
# 1. Постройте распределение признака **"Возраст"**. Опишите распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится возраст большинства соискателей? Есть ли аномалии для признака возраста, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Загрузка данных
file_path = 'data/dst-3.0_16_1_hh_database.csv'
data = pd.read_csv(file_path, sep=';')

def extract_gender_and_age(text):
    # Разделение строки на компоненты
    parts = text.split(',')
    # Извлечение пола
    gender = 'М' if 'Мужчина' in parts[0] else 'Ж'
    # Извлечение возраста
    age = int(parts[1].split()[0])
    return gender, age

# Применение функции и создание новых столбцов
data['Пол'], data['Возраст'] = zip(*data['Пол, возраст'].apply(extract_gender_and_age))

# Удаление старого столбца 'Пол, возраст'
data.drop('Пол, возраст', axis=1, inplace=True)

# Построение гистограммы
plt.figure(figsize=(12, 6))
sns.histplot(data['Возраст'], bins=30, kde=True)
plt.title('Распределение возраста соискателей')
plt.xlabel('Возраст')
plt.ylabel('Количество соискателей')
#histogram_path = 'data/age_distribution_histogram.png'
#plt.savefig(histogram_path)
#plt.close()
plt.show()

# Построение коробчатой диаграммы
plt.figure(figsize=(8, 6))
sns.boxplot(x=data['Возраст'])
plt.title('Коробчатая диаграмма возраста соискателей')
plt.xlabel('Возраст')
#boxplot_path = 'data/age_distribution_boxplot.png'
#plt.savefig(boxplot_path)
#plt.close()
plt.show()
# Мода распределения
age_mode = data['Возраст'].mode()[0]

# Предельные значения и квартили
age_min = data['Возраст'].min()
age_max = data['Возраст'].max()
age_quantiles = data['Возраст'].quantile([0.25, 0.75])

age_mode, age_min, age_max, age_quantiles
# Out:
# (30,
#  14,
#  100,
#  0.25    27.0
#  0.75    36.0
#  Name: Возраст, dtype: float64)

# %% [markdown]
# Распределение возраста соискателей в анализируемом датасете выглядит следующим образом:
#
# 1. Мода распределения: Мода, то есть наиболее часто встречающееся значение возраста среди соискателей, составляет 30 лет.
#
# 2. Предельные значения возраста:
#    - Минимальный возраст соискателей: 14 лет.
#    - Максимальный возраст соискателей: 100 лет.
#
# 3. Квартили распределения:
#    - 25-й квартиль (нижний квартал): 27 лет, что означает, что 25% соискателей имеют возраст до 27 лет включительно.
#    - 75-й квартиль (верхний квартал): 36 лет, что указывает на то, что 75% соискателей моложе 36 лет.
#
# 4. Аномалии в распределении возраста: Наличие значений как 14, так и 100 лет может указывать на наличие аномалий в данных. Значения в районе 100 лет могут быть ошибками ввода или искусственными заполнениями, так как они крайне необычны для рабочей популяции. Также возраст 14 лет находится на границе трудового возраста и может быть нехарактерен для большинства профессий.
#
# На гистограмме видно, что большинство соискателей находится в возрастном диапазоне примерно от 20 до 40 лет, что соответствует общему тренду на рынке труда. Коробчатая диаграмма дополнительно подтверждает наличие выбросов, особенно в верхней части распределения.

# %% [markdown]
# 2. Постройте распределение признака **"Опыт работы (месяц)"**. Опишите данное распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится опыт работы большинства соискателей? Есть ли аномалии для признака опыта работы, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
# Повторная загрузка обновленных данных
file_path = 'data/dst-3.0_16_1_hh_database.csv'
data = pd.read_csv(file_path, sep=';')

# Функция для извлечения опыта работы в месяцах
def get_experience(arg):
    if arg is np.nan or arg == "Не указано":
        return np.nan
    year_list = ['год', 'года', 'лет']
    months_list = ['месяц', 'месяцев', 'месяца']
    list_exp = arg.split()[2:7]
    years = 0
    months = 0
    for index, item in enumerate(list_exp):
        if item in year_list:
            years = int(list_exp[index-1])
        if item in months_list:
            months = int(list_exp[index-1])
    return int(years*12 + months)
    
# Применение функции к датасету
data["Опыт работы (месяц)"] = data["Опыт работы"].apply(get_experience)

# Удаление неиспользуемой колонки
data.drop('Опыт работы', axis=1, inplace=True)

# Построение гистограммы
plt.figure(figsize=(10, 6))
sns.histplot(data['Опыт работы (месяц)'].dropna(), bins=30, kde=True)
plt.title('Распределение опыта работы соискателей (в месяцах)')
plt.xlabel('Опыт работы (месяц)')
plt.ylabel('Количество соискателей')
#histogram_path = 'data/experience_distribution_histogram.png'
#plt.savefig(histogram_path)
#plt.close()
plt.show()
# Построение коробчатой диаграммы
plt.figure(figsize=(8, 6))
sns.boxplot(x=data['Опыт работы (месяц)'])
plt.title('Коробчатая диаграмма опыта работы (месяц)')
plt.xlabel('Опыт работы (месяц)')
#boxplot_path = 'data/experience_distribution_boxplot.png'
#plt.savefig(boxplot_path)
#plt.close()
plt.show()
# Расчет моды, минимального, максимального значений и определение аномалий
experience_mode = data['Опыт работы (месяц)'].mode()[0]
experience_min = data['Опыт работы (месяц)'].min()
experience_max = data['Опыт работы (месяц)'].max()
experience_quantiles = data['Опыт работы (месяц)'].quantile([0.25, 0.75])
median_experience = data['Опыт работы (месяц)'].median()

experience_mode, experience_min, experience_max, experience_quantiles, median_experience
# Out:
# (81.0,
#  1.0,
#  1188.0,
#  0.25     57.0
#  0.75    154.0
#  Name: Опыт работы (месяц), dtype: float64,
#  100.0)

# %% [markdown]
# *Модальное значение опыта работы равно 81 месяцу, в интервале от 57 до 154 месяцев находится опыт работы большинства соискателей. Получается большинство соискателей начав свою трудовую деятельность сразу после окончания учебного заведения 20-24 года, прорабатывают около 7 лет, и начианют искать новое место работы. По методу Тьюки зафиксировано 1276 аномальных наблюдения, которые в 1,5 раза превышают межквартильный размах.*

# %% [markdown]
# Распределение опыта работы соискателей в месяцах представлено на гистограмме и коробчатой диаграмме. Вот анализ полученных результатов:
#
# 1. Мода распределения: Самый частый опыт работы среди соискателей составляет 81 месяц.
#
# 2. Предельные значения опыта работы:
#    - Минимальный опыт работы: 1 месяц.
#    - Максимальный опыт работы: 1188 месяцев (что эквивалентно примерно 99 годам).
#
# 3. Квартили распределения:
#    - 25-й квартиль: 57 месяцев.
#    - 75-й квартиль: 154 месяца.
#
# 4. Медиана опыта работы: Медиана опыта работы составляет 100 месяцев, что указывает на то, что половина соискателей имеет опыт работы меньше 100 месяцев, а другая половина - больше.
#
# 5. Аномалии в распределении опыта работы: Наибольший опыт работы в 1188 месяцев кажется необычно высоким и может рассматриваться как аномалия или ошибка в данных. Также стоит обратить внимание на другие значительно высокие значения, которые могут быть выбросами и не отражать типичный опыт работы.
#
# 6. Гистограмма и коробчатая диаграмма: На гистограмме видно, что большинство соискателей имеет опыт работы в диапазоне от нескольких десятков до нескольких сотен месяцев. Коробчатая диаграмма подтверждает наличие выбросов, особенно для очень высоких значений опыта работы.

# %% [markdown]
# 3. Постройте распределение признака **"ЗП (руб)"**. Опишите данное распределение, отвечая на следующие вопросы: каковы предельные значения признака, в каком примерном интервале находится заработная плата большинства соискателей? Есть ли аномалии для признака возраста? Обратите внимание на гигантские размеры желаемой заработной платы.
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
# Загрузка данных о курсах валют и базы данных соискателей
file_path_currency_rates = 'data/ExchangeRates.csv'
file_path_data = 'data/dst-3.0_16_1_hh_database.csv'

currency_rates = pd.read_csv(file_path_currency_rates, sep=',')
data = pd.read_csv(file_path_data, sep=';')

# Функция для определения валюты из признака 'ЗП'
def currency(feature):
    currency_names = {
        'грн': 'UAH', 'USD': 'USD', 'EUR': 'EUR', 'белруб': 'BYN',
        'KGS': 'KGS', 'сум': 'UZS', 'AZN': 'AZN', 'KZT': 'KZT'
    }
    return currency_names.get(feature.split()[1].replace('.',''))

# Функция для конвертации ЗП в рубли
def salary_RUB(features):
    if np.isnan(features)[1]:
        return features[0]
    else:
        return features[0] * features[1] / features[2]

# Обработка данных о курсах валют
ExchangeRates = pd.read_csv(file_path_currency_rates)
ExchangeRates['date'] = pd.to_datetime(ExchangeRates['date'])
ExchangeRates = ExchangeRates.drop(['per', 'time', 'vol'], axis=1)

# Преобразование данных
data['Валюта'] = data['ЗП'].apply(currency)
data['ЗП'] = data['ЗП'].apply(lambda x: float(x.split()[0]))
data['Обновление резюме'] = pd.to_datetime(data['Обновление резюме']).dt.date.astype('datetime64[ns]')
data = data.merge(ExchangeRates, how='left', left_on=['Валюта', 'Обновление резюме'], 
                  right_on=['currency', 'date'])
data['ЗП (руб)'] = data[['ЗП', 'close', 'proportion']].apply(salary_RUB, axis=1)
data = data.drop(['ЗП', 'Валюта', 'currency', 'date', 'close', 'proportion'], axis=1)

# Построение гистограммы и коробчатой диаграммы для признака "ЗП (руб)"
plt.figure(figsize=(15, 6))

# Гистограмма
plt.subplot(1, 2, 1)
sns.histplot(data['ЗП (руб)'].dropna(), bins=30, kde=True)
plt.title('Распределение желаемой ЗП (в рублях) соискателей')
plt.xlabel('ЗП (руб)')
plt.ylabel('Количество соискателей')

# Коробчатая диаграмма
plt.subplot(1, 2, 2)
sns.boxplot(x=data['ЗП (руб)'].dropna())
plt.title('Коробчатая диаграмма желаемой ЗП (в рублях) соискателей')
plt.xlabel('ЗП (руб)')

plt.tight_layout()
plt.show()

# Расчет статистических показателей
salary_mode = data['ЗП (руб)'].mode()[0]
salary_min = data['ЗП (руб)'].min()
salary_max = data['ЗП (руб)'].max()
salary_quantiles = data['ЗП (руб)'].quantile([0.25, 0.75])
median_salary = data['ЗП (руб)'].median()

salary_mode, salary_min, salary_max, salary_quantiles, median_salary
# Out:
# (50000.0,
#  1.0,
#  24304876.0,
#  0.25    37082.2
#  0.75    95000.0
#  Name: ЗП (руб), dtype: float64,
#  59019.0)

# %% [markdown]
# Распределение желаемой заработной платы (в рублях) соискателей было проанализировано с помощью гистограммы и коробчатой диаграммы. Вот ключевые выводы:
#
# 1. Мода распределения: Мода, то есть наиболее часто встречающаяся заработная плата среди соискателей, составляет 50,000 рублей.
#
# 2. Предельные значения заработной платы:
#    - Минимальная желаемая ЗП: 1 рубль.
#    - Максимальная желаемая ЗП: 24,304,876 рублей.
#
# 3. Квартили распределения:
#    - 25-й квартиль: 37,082.2 рублей.
#    - 75-й квартиль: 95,000 рублей.
#
# 4. Медиана желаемой заработной платы**: Медианная заработная плата составляет 59,019 рублей.
#
# 5. Аномалии в распределении:
#    - Наличие желаемой заработной платы в размере 24 миллиона рублей и других очень высоких значений может указывать на наличие аномалий в данных.
#    - Распределение имеет длинный правый "хвост", что обычно свидетельствует о наличии значительного числа выбросов.
#
# 6. Гистограмма и коробчатая диаграмма:
#    - Гистограмма показывает, что большинство соискателей указывает желаемую заработную плату в диапазоне от нескольких десятков тысяч до нескольких сотен тысяч рублей.
#    - Коробчатая диаграмма подчеркивает наличие выбросов с очень высокими значениями заработной платы.
#
# У 5 соискателей желаемая ЗП состовляет более 1 млн. руб.

# %% [markdown]
# 4. Постройте диаграмму, которая показывает зависимость **медианной** желаемой заработной платы (**"ЗП (руб)"**) от уровня образования (**"Образование"**). Используйте для диаграммы данные о резюме, где желаемая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по представленной диаграмме: для каких уровней образования наблюдаются наибольшие и наименьшие уровни желаемой заработной платы? Как вы считаете, важен ли признак уровня образования при прогнозировании заработной платы?*

# %%
# ваш код здесь
import pandas as pd

# Загрузка данных
data = pd.read_csv('data/dst-final_hh_database.csv', sep=';')

# Фильтрация данных по желаемой заработной плате меньше 1 миллиона рублей
filtered_data = data[data['ЗП (руб)'] < 1000000]

# Группировка по уровню образования и расчет медианных значений зарплаты
median_salaries = filtered_data.groupby('Образование')['ЗП (руб)'].median()

# Построение диаграммы
plt.figure(figsize=(10, 6))
median_salaries.plot(kind='bar')
plt.title('Медианная желаемая заработная плата по уровню образования')
plt.xlabel('Уровень образования')
plt.ylabel('Медианная заработная плата (руб.)')
plt.xticks(rotation=45)
plt.show()


# Построение коробчатой диаграммы для медианных значений зарплаты по уровню образования
plt.figure(figsize=(10, 6))
sns.boxplot(x='Образование', y='ЗП (руб)', data=filtered_data)
plt.title('Распределение желаемой заработной платы по уровню образования')
plt.xlabel('Уровень образования')
plt.ylabel('Желаемая заработная плата (руб.)')
plt.xticks(rotation=45)
plt.show()

# Определение категории образования с наивысшей медианной зарплатой
highest_paid_education_category = median_salaries.idxmax()

highest_paid_education_category
# Out:
# 'высшее'

# %% [markdown]
# На представленной диаграмме показана зависимость медианной желаемой заработной платы от уровня образования соискателей, при условии, что желаемая зарплата меньше 1 миллиона рублей. Вот ключевые выводы:
#
# 1. Наибольший уровень желаемой заработной платы наблюдается у соискателей с высшим образованием. Это означает, что кандидаты с высшим образованием в среднем стремятся получать большую заработную плату по сравнению с другими уровнями образования.
#
# 2. Наименьший уровень желаемой заработной платы наблюдается у соискателей с образованием, не указанным в данных или относящимся к более низким уровням (например, среднее специальное или среднее образование).
#
# 3. Важность признака уровня образования**: Уровень образования является важным фактором при прогнозировании заработной платы. В целом, кандидаты с более высоким уровнем образования имеют тенденцию ожидать более высокую заработную плату, что может отражать как их квалификацию, так и требования рынка труда к определенным специализациям.

# %% [markdown]
# 5. Постройте диаграмму, которая показывает распределение желаемой заработной платы (**"ЗП (руб)"**) в зависимости от города (**"Город"**). Используйте для диаграммы данные о резюме, где желая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по полученной диаграмме: как соотносятся медианные уровни желаемой заработной платы и их размах в городах? Как вы считаете, важен ли признак города при прогнозировании заработной платы?*

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Загрузка данных
data = pd.read_csv('data/dst-final_hh_database.csv', sep=';')

# Отбор данных с желаемой зарплатой меньше 1 миллиона рублей
filtered_data = data[data['ЗП (руб)'] < 1000000]

# Построение графика
plt.figure(figsize=(12, 6))
sns.boxplot(x='Город', y='ЗП (руб)', data=filtered_data)
plt.title('Распределение желаемой заработной платы по городам')
plt.xlabel('Город')
plt.ylabel('Желаемая заработная плата (руб.)')
plt.xticks(rotation=45)
plt.show()
max_salary_city = filtered_data[filtered_data['ЗП (руб)'] == filtered_data['ЗП (руб)'].max()]['Город'].iloc[0]
salary_max = filtered_data['ЗП (руб)'].max()
print(f"Город с наибольшим показателем желаемой заработной платы: {max_salary_city}")
print(f"Наибольший показатель желаемой заработной платы: {salary_max}")
# Out:
# Город с наибольшим показателем желаемой заработной платы: другие
# Наибольший показатель желаемой заработной платы: 923983.0

# %% [markdown]
# На демонстрируемой визуализации отображено распределение ожидаемых зарплатных уровней в зависимости от городов. На основе этого графика можно сделать несколько ключевых наблюдений:
#
# 1. Уровень и Диапазон Заработных Плат: В Москве заметно самые высокие медианные значения и размах ожидаемых заработных плат. За Москвой следует Санкт-Петербург с несколько более низкими показателями. В городах-миллионниках и в других городах наблюдаются схожие и более низкие уровни ожидаемых зарплат.
#
# 2. Максимальная Желаемая Заработная Плата: Самый высокий уровень желаемой заработной платы, который достигает приблизительно 923.983 тысяч рублей, зафиксирован в категории "другие" города. Это указывает на то, что в некоторых случаях меньшие по размеру города могут предлагать высокие зарплаты для специфических, возможно высококвалифицированных должностей.
#
# 3. Значимость Города в Прогнозировании Зарплат: Анализ показывает, что городской фактор играет значительную роль в определении ожидаемой заработной платы. Объединение городов-миллионников и других городов в одну категорию может быть полезным для более общего анализа рынка труда, но в то же время может скрывать значимые различия в рамках этих групп.

# %% [markdown]
# 6. Постройте **многоуровневую столбчатую диаграмму**, которая показывает зависимость медианной заработной платы (**"ЗП (руб)"**) от признаков **"Готовность к переезду"** и **"Готовность к командировкам"**. Проанализируйте график, сравнив уровень заработной платы в категориях.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Загрузка данных
currency_rates = pd.read_csv('data/ExchangeRates.csv', sep=',')
data = pd.read_csv('data/dst-m2_education_experience_age_gender_hh_database.csv', sep=';')

# Функция для определения валюты из признака 'ЗП'
def currency(feature):
    currency_names = {
                'грн': 'UAH', 'USD': 'USD', 'EUR': 'EUR', 'белруб': 'BYN',
                'KGS': 'KGS', 'сум': 'UZS', 'AZN': 'AZN', 'KZT': 'KZT'
                }
    return currency_names.get(feature.split()[1].replace('.',''))

# Функция для создания нового признака 'ЗП (руб)'
def salary_RUB(features):
    if np.isnan(features[1]):
        return features[0]
    else:
        return features[0] * features[1] / features[2]

# Обработка данных
currency_rates['date'] = pd.to_datetime(currency_rates['date'])
exchange_rates = currency_rates.drop(['per', 'time', 'vol'], axis=1)

data['Валюта'] = data['ЗП'].apply(currency)
data['ЗП'] = data['ЗП'].apply(lambda x: float(x.split()[0]))
data['Обновление резюме'] = pd.to_datetime(data['Обновление резюме']).dt.date.astype('datetime64[ns]')

data = data.merge(exchange_rates, how='left', left_on=['Валюта', 'Обновление резюме'], 
                  right_on=['currency', 'date'])

data['ЗП (руб)'] = data[['ЗП', 'close', 'proportion']].apply(salary_RUB, axis=1)
data = data.drop(['ЗП', 'Валюта', 'currency', 'date', 'close', 'proportion'], axis=1)

# Вычисление медианной заработной платы
median_salary = round(data['ЗП (руб)'].median() / 1000)
print('Желаемая медианная заработная плата соискателей: {} тыс. рублей'.format(median_salary))

# Построение многоуровневой столбчатой диаграммы
pivot = data.pivot_table(index='Готовность к переезду', columns='Готовность к командировкам', 
                         values='ЗП (руб)', aggfunc='median')

pivot.plot(kind='bar', figsize=(10, 6))
plt.title('Медианная заработная плата в зависимости от готовности к переезду и командировкам')
plt.xlabel('Готовность к переезду')
plt.ylabel('Медианная заработная плата (руб.)')
plt.xticks(rotation=0)
plt.show()

# Определение медианной заработной платы для соискателей, готовых и к переезду, и к командировкам
median_salary_ready_for_both = data[(data['Готовность к переезду'] == True) & 
                                   (data['Готовность к командировкам'] == True)]['ЗП (руб)'].median()

# Преобразование в тысячи рублей и округление
median_salary_thousands = round(median_salary_ready_for_both / 1000)

print("Медианная желаемая заработная плата (тыс. руб.) для соискателей, готовых и к переезду, и к командировкам:", median_salary_thousands)
# Out:
# Желаемая медианная заработная плата соискателей: 59 тыс. рублей
# Медианная желаемая заработная плата (тыс. руб.) для соискателей, готовых и к переезду, и к командировкам: 66

# %% [markdown]
# Анализируя уровень запрашиваемой заработной платы в контексте готовности кандидатов к переезду и командировкам, можно сделать интересные выводы:
#
# 1. Наблюдается заметное увеличение средней ожидаемой заработной платы с 40 до 50 тысяч рублей для тех соискателей, которые готовы к переезду. Это может отражать их готовность к более широкому кругу возможностей и готовность адаптироваться к новым условиям и среде.
#
# 2. Для соискателей, готовых к командировкам, средняя ожидаемая зарплата ещё выше, увеличиваясь с 60 до приблизительно 66 тысяч рублей. Это может быть связано с тем, что командировки часто связаны с дополнительными неудобствами, такими как временное отсутствие дома и необходимость адаптации к различным рабочим условиям.
#
# Из этого следует, что кандидаты, по всей видимости, ценят готовность к командировкам выше, чем готовность к переезду. Это может быть связано с тем, что командировки часто воспринимаются как более трудоёмкие и требующие большей компенсации, особенно учитывая временное разлучение с семьёй и изменение привычного образа жизни.
#
# Таким образом, предпочтения и ожидания соискателей в отношении заработной платы могут значительно меняться в зависимости от их готовности к географической мобильности и временным изменениям в стандартных условиях работы.

# %% [markdown]
# 7. Постройте сводную таблицу, иллюстрирующую зависимость **медианной** желаемой заработной платы от возраста (**"Возраст"**) и образования (**"Образование"**). На полученной сводной таблице постройте **тепловую карту**. Проанализируйте тепловую карту, сравнив показатели внутри групп.

# %%
# ваш код здесь
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


# Загрузка данных
data = pd.read_csv('data/dst-final_hh_database.csv', sep=',')
# Создание сводной таблицы
pivot_table = data.pivot_table(values='ЗП (руб)', index='Образование', columns='Возраст', aggfunc='median')

# Построение тепловой карты
plt.figure(figsize=(12, 8))
sns.heatmap(pivot_table, annot=True, fmt=".0f", cmap='YlGnBu')
plt.title('Медианная заработная плата в зависимости от возраста и образования')
plt.xlabel('Возраст')
plt.ylabel('Образование')
plt.show()

# %% [markdown]
# Анализ данных показывает, что в сегменте среднего образования диапазон возрастов кандидатов варьируется от 15 до 59 лет, что кажется более реалистичным по сравнению с категорией высшего образования. В последней категории зафиксированы крайне широкие возрастные рамки - от 14 до приблизительно 80 лет, что выглядит несколько необычно. Стоит заметить, что соискатели с высшим образованием, которым меньше 21 года, являются исключением, а не правилом, что указывает на потенциальную неточность в данных. Подобная ситуация наблюдается и в категории среднего специального образования, где обычный возраст окончания обучения - 19-20 лет.
#
# При рассмотрении более реалистических возрастных границ, наблюдается тенденция к росту ожидаемой заработной платы с возрастом. Самые высокие показатели зарплаты зафиксированы у кандидатов с высшим образованием в возрастной группе от 38 до 48 лет и у тех, у кого образование незаконченное высшее, в возрасте от 41 до 50 лет.
#
# В сегменте соискателей со средним специальным образованием максимальный уровень ожидаемой заработной платы обычно достигается в возрасте около 30 лет, после чего наблюдается стабильность с небольшими колебаниями. Для категории среднего образования характерны умеренные колебания в ожиданиях по зарплате на протяжении всего возрастного периода.

# %% [markdown]
# 8. Постройте **диаграмму рассеяния**, показывающую зависимость опыта работы (**"Опыт работы (месяц)"**) от возраста (**"Возраст"**). Опыт работы переведите из месяцев в года, чтобы признаки были в едином масштабе. Постройте на графике дополнительно прямую, проходящую через точки (0, 0) и (100, 100). Данная прямая соответствует значениям, когда опыт работы равен возрасту человека. Точки, лежащие на этой прямой и выше нее - аномалии в наших данных (опыт работы больше либо равен возрасту соискателя)

# %%
import matplotlib.pyplot as plt
# Загрузка данных
data = pd.read_csv('data/dst-final_hh_database.csv', sep=';')
# Convert experience from months to years
data['Опыт работы (год)'] = data['Опыт работы (месяц)'] / 12

# Create scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(data['Возраст'], data['Опыт работы (год)'], alpha=0.6, edgecolors='w', s=80)

# Plot the line from (0, 0) to (100, 100)
plt.plot([0, 100], [0, 100], color='red', linestyle='-', linewidth=2)

# Labeling the plot
plt.title('Зависимость опыта работы от возраста', fontsize=14)
plt.xlabel('Возраст', fontsize=12)
plt.ylabel('Опыт работы (годы)', fontsize=12)
plt.grid(True)

# Show the plot
plt.show()

# Count the number of points above the line
above_line_count = data[data['Опыт работы (год)'] > data['Возраст']].shape[0]
above_line_count
# Out:
# 7

# %% [markdown]
# Один из заметных аспектов, выделяющихся при анализе данных, - это очевидная корреляция между опытом работы и возрастом соискателей. Однако на диаграмме присутствуют аномальные точки, где указанный опыт работы сопоставим с возрастом кандидата или даже превышает его. Это, скорее всего, указывает на ошибки ввода данных.
#
# Из анализа также следует, что кандидаты в диапазоне возраста от 15 до 50 лет демонстрируют разнообразный опыт работы, начиная от нуля и достигая максимально возможного. В то время как большинство соискателей старше 50 лет имеют опыт работы в промежутке от нескольких лет до максимально возможного. Наиболее распространенной комбинацией является 31 год возраста и 8 лет опыта работы, что представляет собой типичный пик в распределении.

# %% [markdown]
# **Дополнительные баллы**
#
# Для получения 2 дополнительных баллов по разведывательному анализу постройте еще два любых содержательных графика или диаграммы, которые помогут проиллюстрировать влияние признаков/взаимосвязь между признаками/распределения признаков. Приведите выводы по ним. Желательно, чтобы в анализе участвовали признаки, которые мы создавали ранее в разделе "Преобразование данных".

# %%
# ваш код здесь
import matplotlib.pyplot as plt
# Загрузка данных
filtered_data = pd.read_csv('data/dst-final_hh_database.csv', sep=';')

# Группировка данных по возрасту и полу, вычисление медианной заработной платы для каждой группы
median_salary_by_age_gender = filtered_data.groupby(['Возраст', 'Пол'])['ЗП (руб)'].median().reset_index()

# Создание диаграммы
plt.figure(figsize=(12, 6))
sns.lineplot(x='Возраст', y='ЗП (руб)', hue='Пол', data=median_salary_by_age_gender)

# Настройка заголовков и меток осей
plt.title('Распределение медианной желаемой заработной платы по возрасту и полу')
plt.xlabel('Возраст')
plt.ylabel('Медианная желаемая заработная плата (руб)')

# Отображение графика
plt.show()

# %% [markdown]
# Анализ диаграммы медианной желаемой заработной платы по возрасту с разделением по полу выявляет несколько ключевых наблюдений:
#
# Различия в зарплатных ожиданиях между мужчинами и женщинами: На протяжении большей части возрастного диапазона наблюдается тенденция к более высоким зарплатным ожиданиям у мужчин по сравнению с женщинами. Это может отражать общую тенденцию различий в заработной плате между полами на рынке труда.
#
# Ранний рост зарплатных ожиданий: Для обоих полов виден рост зарплатных ожиданий в начальной стадии карьеры, что, вероятно, связано с накоплением опыта и профессионального роста.
#
# Стабилизация в среднем возрасте: По мере приближения к среднему возрасту (примерно 30-50 лет) зарплатные ожидания становятся более стабильными, с небольшими различиями между полами. Это может отражать период, когда люди достигают определенного уровня в своей профессиональной карьере.
#
# Изменения в пожилом возрасте: В более старших возрастных группах (после 50-60 лет) наблюдается более заметное снижение зарплатных ожиданий, особенно у мужчин. Это может быть связано с переходом к менее ответственным должностям, уменьшением объема работы или подготовкой к выходу на пенсию.
#
# Возможные причины различий: Различия в зарплатных ожиданиях между мужчинами и женщинами могут быть обусловлены множеством факторов, включая социальные нормы, различия в выборе профессии, образовании, наличии карьерных перерывов, связанных с семейными обстоятельствами, и другими системными факторами.
#
# Эти наблюдения предоставляют важные инсайты о том, как пол и возраст могут влиять на зарплатные ожидания на рынке труда. Однако следует отметить, что данные основаны на желаемой заработной плате, а не на фактических доходах, и не учитывают другие важные факторы, такие как образование, отрасль и регион.

# %%
import matplotlib.pyplot as plt
# Загрузка данных
data = pd.read_csv('data/dst-final_hh_database.csv', sep=';')

# Подсчет количества соискателей по полу и уровню образования
education_distribution_by_gender = data.groupby(['Пол', 'Образование']).size().unstack(fill_value=0)

# Создание круговых диаграмм для каждого пола
fig, ax = plt.subplots(1, 2, figsize=(14, 7))

# Диаграмма для мужчин
ax[0].pie(education_distribution_by_gender.loc['М', :], labels=education_distribution_by_gender.columns, autopct='%1.1f%%', startangle=140)
ax[0].set_title('Уровень образования среди мужчин')

# Диаграмма для женщин
ax[1].pie(education_distribution_by_gender.loc['Ж', :], labels=education_distribution_by_gender.columns, autopct='%1.1f%%', startangle=140)
ax[1].set_title('Уровень образования среди женщин')

# Отображение графиков
plt.show()

# %% [markdown]
# Анализ круговых диаграмм, отображающих общее соотношение уровней образования среди мужчин и женщин, выявляет несколько ключевых аспектов:
#
# 1. Сходство в распределении образования: обеих диаграммах можно заметить схожее распределение различных уровней образования. Это указывает на то, что в целом мужчины и женщины имеют сопоставимые образовательные уровни в представленной выборке данных.
#
# 2. Доминирование высшего образования: Наибольшую долю в обоих случаях занимают соискатели с высшим образованием. Это подчеркивает значимость высшего образования в современном рынке труда.
#
# 3. Незначительные различия между полами: Могут быть небольшие различия в процентном соотношении уровней образования между мужчинами и женщинами, что может отражать тенденции в выборе образовательного пути или доступности образования для разных полов.
#
# 4. Разнообразие образовательных уровней: Обе диаграммы демонстрируют присутствие кандидатов с различными уровнями образования, от среднего специального до научных степеней, что отражает разнообразие образовательных возможностей и карьерных путей.
#
#
# В целом, данные диаграммы предоставляют интересную информацию о распределении образовательных уровней среди мужчин и женщин, подчеркивая важность высшего образования в обеих группах и указывая на схожесть образовательного уровня между полами.

# %% [markdown]
# # Очистка данных

# %% [markdown]
# 1. Начнем с дубликатов в наших данных. Найдите **полные дубликаты** в таблице с резюме и удалите их.

# %%
# ваш код здесь
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Загрузка данных
data = pd.read_csv('data/dst-final_hh_database.csv', sep=';')

# Подсчет количества полных дубликатов
duplicates_count = data.duplicated().sum()

# Удаление полных дубликатов
data_cleaned = data.drop_duplicates()
# Сохранение изменённого DataFrame в файл
output_file_path = 'data/dst-without_doubles_final_hh_database.csv'
data_cleaned.to_csv(output_file_path, sep=';', index=False)

print("Количество удаленных дубликатов:", duplicates_count)
data_cleaned.info()
# Out:
# Количество удаленных дубликатов: 161
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44583 entries, 0 to 44743
# Data columns (total 23 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Ищет работу на должность:        44583 non-null  object
#  1   Последнее/нынешнее место работы  44582 non-null  object
#  2   Последняя/нынешняя должность     44581 non-null  object
#  3   Обновление резюме                44583 non-null  object
#  4   Авто                             44583 non-null  object
#  5   Образование                      44583 non-null  object
#  6   Пол                              44583 non-null  object
#  7   Возраст                          44583 non-null  int64
#  8   Опыт работы (месяц)              44417 non-null  float64
#  9   Город                            44583 non-null  object
#  10  Готовность к переезду            44583 non-null  bool
# ...

# %% [markdown]
# 2. Займемся пропусками. Выведите информацию **о числе пропусков** в столбцах.

# %%
# ваш код здесь
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Загрузка данных
data = pd.read_csv('data/dst-final_hh_database.csv', sep=';')

# Подсчет пропусков в каждом столбце
missing_values = data.isnull().sum()

# Определение количества пропусков в столбце 'Опыт работы (месяц)'
missing_experience = missing_values['Опыт работы (месяц)']

print("Количество пропусков в столбце 'Опыт работы (месяц)':", missing_experience)
# Out:
# Количество пропусков в столбце 'Опыт работы (месяц)': 168

# %% [markdown]
# 3. Итак, у нас есть пропуски в 3ех столбцах: **"Опыт работы (месяц)"**, **"Последнее/нынешнее место работы"**, **"Последняя/нынешняя должность"**. Поступим следующим образом: удалите строки, где есть пропуск в столбцах с местом работы и должностью. Пропуски в столбце с опытом работы заполните **медианным** значением.

# %%
# ваш код здесь
data = pd.read_csv('data/dst-without_doubles_final_hh_database.csv', sep=';')

# Удаление строк, где есть пропуск в столбцах с местом работы и должностью
data.dropna(subset=['Последнее/нынешнее место работы', 'Последняя/нынешняя должность'], inplace=True)

# Заполнение пропусков в столбце с опытом работы медианным значением
median_experience = data['Опыт работы (месяц)'].median()
data['Опыт работы (месяц)'].fillna(median_experience, inplace=True)

# Рассчет среднего значения в столбце 'Опыт работы (месяц)'
average_experience = data['Опыт работы (месяц)'].mean()
average_experience_rounded = round(average_experience)

# Сохранение изменённого DataFrame в файл
output_file_path = 'data/dst-without_doubles_final2_hh_database.csv'
data.to_csv(output_file_path, sep=';', index=False)

average_experience_rounded
# Out:
# 114

# %% [markdown]
# 4. Мы добрались до ликвидации выбросов. Сначала очистим данные вручную. Удалите резюме, в которых указана заработная плата либо выше 1 млн. рублей, либо ниже 1 тыс. рублей.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# Загружаем данные из файла в DataFrame
data = pd.read_csv('data/dst-without_doubles_final2_hh_database.csv', sep=';')

# Удаляем выбросы: ЗП выше 1 миллиона рублей или ниже 1 тысячи рублей
outliers = data[(data['ЗП (руб)'] > 1000000) | (data['ЗП (руб)'] < 1000)]

# Количество найденных выбросов
number_of_outliers = outliers.shape[0]
number_of_outliers
# Out:
# 89

# %% [markdown]
# 5. В процессе разведывательного анализа мы обнаружили резюме, в которых **опыт работы в годах превышал возраст соискателя**. Найдите такие резюме и удалите их из данных

# %%
# ваш код здесь
import pandas as pd
import numpy as np

# У нас есть DataFrame df и в нем есть столбцы 'Опыт работы (месяц)' и 'Возраст'
df = pd.read_csv('data/dst-without_doubles_final2_hh_database.csv', sep=';')

# Преобразование опыта работы из месяцев в года
df['Опыт работы (год)'] = df['Опыт работы (месяц)'] / 12

# Удаление строк, где опыт работы в годах больше, чем возраст соискателя
outliers = df[df['Опыт работы (год)'] > df['Возраст']]
df_cleaned = df.drop(outliers.index)

# Сохранение изменённого DataFrame в файл
output_file_path = 'data/dst-without_doubles_final3_hh_database.csv'
df_cleaned.to_csv(output_file_path, sep=';', index=False)

# Вывод количества найденных выбросов
num_outliers = outliers.shape[0]

print(num_outliers)
# Out:
# 7

# %% [markdown]
# 6. В результате анализа мы обнаружили потенциальные выбросы в признаке **"Возраст"**. Это оказались резюме людей чересчур преклонного возраста для поиска работы. Попробуйте построить распределение признака в **логарифмическом масштабе**. Добавьте к графику линии, отображающие **среднее и границы интервала метода трех сигм**. Напомним, сделать это можно с помощью метода axvline. Например, для построение линии среднего будет иметь вид:
#
# `histplot.axvline(log_age.mean(), color='k', lw=2)`
#
# В какую сторону асимметрично логарифмическое распределение? Напишите об этом в комментарии к графику.
# Найдите выбросы с помощью метода z-отклонения и удалите их из данных, используйте логарифмический масштаб. Давайте сделаем послабление на **1 сигму** (возьмите 4 сигмы) в **правую сторону**.
#
# Выведите таблицу с полученными выбросами и оцените, с каким возрастом соискатели попадают под категорию выбросов?

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Загрузка данных
data_path = 'data/dst-without_doubles_final3_hh_database.csv'
data = pd.read_csv(data_path, sep=';')

# Извлечение данных возраста и преобразование в логарифмический масштаб
age_data = data['Возраст']
log_age = np.log(age_data)

# Построение распределения возраста в логарифмическом масштабе
plt.figure(figsize=(10, 6))
histplot = sns.histplot(log_age, kde=True, color='blue')

# Расчет среднего значения и стандартного отклонения
mean_age = log_age.mean()
std_age = log_age.std()

# Добавление линий среднего значения и границ интервала (3 сигмы)
histplot.axvline(mean_age, color='k', lw=2, label='Среднее')
histplot.axvline(mean_age - 3 * std_age, color='red', ls='--', lw=2, label='3 Сигмы нижняя граница')
histplot.axvline(mean_age + 3 * std_age, color='green', ls='--', lw=2, label='3 Сигмы верхняя граница')

# Настройка отображения графика
plt.title('Логарифмическое распределение возраста соискателей')
plt.xlabel('Логарифм Возраста')
plt.ylabel('Количество')
plt.legend()

# Определение асимметрии распределения
skewness = log_age.skew()
skewness_direction = 'правосторонняя' if skewness > 0 else 'левосторонняя'

# Показать график
plt.show()

# Вывод информации о направлении асимметрии распределения
skewness, skewness_direction
# Out:
# (0.45200543412804983, 'правосторонняя')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# Загрузка данных
data_path = 'data/dst-without_doubles_final3_hh_database.csv'
data = pd.read_csv(data_path, sep=';')


# Функция для определения выбросов по методу Z-отклонений
def outliers_z_score_mod(data, feature, log_scale=False, left=3, right=4):
    if log_scale:
        x = np.log(data[feature] + 1)
    else:
        x = data[feature]
    
    mu = x.mean()
    sigma = x.std()
    lower_bound = mu - left * sigma
    upper_bound = mu + right * sigma

    outliers = data[(x < lower_bound) | (x > upper_bound)]
    cleaned = data[(x >= lower_bound) & (x <= upper_bound)]

    return outliers, cleaned

# Вызов функции для определения и удаления выбросов
outliers, cleaned_data = outliers_z_score_mod(data, 'Возраст', log_scale=True)

# Вывод информации о выбросах и обновленных данных
outliers_count = outliers.shape[0]
cleaned_count = cleaned_data.shape[0]

outliers_count, cleaned_count, outliers.head()
# Out:
# (3,
#  44571,
#              Ищет работу на должность: Последнее/нынешнее место работы  \
#  30975  Менеджер по работе с клиентами           ООО "ФёрстКэшКомпани"
#  32788                 Тестировщик игр                        OOO ЖМЫХ
#  33492            Frontend-разработчик                       Freelance
#
#           Последняя/нынешняя должность Обновление резюме        Авто  \
#  30975  Менеджер по работе с клиентами        2019-06-04  Не указано
#  32788                  Тестировщик ПО        2019-09-04  Не указано
#  33492            Frontend-разработчик        2019-04-19  Не указано
#
#                 Образование Пол  Возраст  Опыт работы (месяц)            Город  \
#  30975              среднее   М       15                  2.0  Санкт-Петербург
#  32788  среднее специальное   М       15                  3.0           другие
#  33492  среднее специальное   М      100                 30.0  Санкт-Петербург
#
# ...

# %% [markdown]
# ваш коммментарий здесь
#
# Распределение логарифмированных значений возраста соискателей работы демонстрирует правостороннюю асимметрию, что видно из положительного значения коэффициента асимметрии (0.452). Это означает, что в распределении больше значений, сосредоточенных слева от среднего, и длинный хвост в правой части графика.
# Теперь я найду выбросы с помощью метода z-отклонения с 4 сигмами в правую сторону и 3 сигмами в левую, затем выведу таблицу с этими выбросами. ​​
# После применения модифицированного метода z-отклонения с 4 сигмами в правую сторону и 3 сигмами в левую, было обнаружено 3 выброса из 44,571 записи. Эти выбросы соответствуют соискателям с необычными значениями возраста:
# Возраст 15 лет – 2 записи.
# Возраст 100 лет – 1 запись.
# Это указывает на то, что соискатели с возрастом 15 лет и 100 лет являются аномальными для данного набора данных и могут быть исключены из дальнейшего анализа. ​​
